# %% [markdown]
# <a href="https://colab.research.google.com/github/luckyHarry/cryptoai/blob/main/cryptoAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# testing whether the csv file can be loaded

# %%
import pandas as pd

df=pd.read_csv('btcusdpartial.csv')

df.tail()

# %% [markdown]
# a gua object can turn wave shape into chinese 64 Gua . and also into latin charactor symbles to  feed for Gpt2

# %%
def gua(row,t1,t2,t3,t4,t5,t6,t7):
    vama1=row['vama{}'.format(t1)]
    vama2=row['vama{}'.format(t2)]
    vama3=row['vama{}'.format(t3)]
    vama4=row['vama{}'.format(t4)]
    vama5=row['vama{}'.format(t5)]
    vama6=row['vama{}'.format(t6)]
    vama7=row['vama{}'.format(t7)]
    is_qian = vama1 > vama2 and vama2 > vama3  and vama3 > vama4 and vama4 > vama5 and vama5 > vama6 and vama6 > vama7
    is_kun = vama1 < vama2 and vama2 < vama3  and vama3 < vama4 and vama4 < vama5 and vama5 < vama6 and vama6 < vama7
    is_guai = vama1 < vama2 and vama2 > vama3  and vama3 > vama4 and vama4 > vama5 and vama5 > vama6 and vama6 > vama7
    is_dayou = vama1 > vama2 and vama2 < vama3  and vama3 > vama4 and vama4 > vama5 and vama5 > vama6 and vama6 > vama7
    is_dazhuang = vama1 < vama2 and vama2 < vama3  and vama3 > vama4 and vama4 > vama5 and vama5 > vama6 and vama6 > vama7
    is_xiaoxu = vama1 > vama2 and vama2 > vama3  and vama3 < vama4 and vama4 > vama5 and vama5 > vama6 and vama6 > vama7
    is_xu = vama1 < vama2 and vama2 > vama3  and vama3 < vama4 and vama4 > vama5 and vama5 > vama6 and vama6 > vama7
    is_daxu = vama1 > vama2 and vama2 < vama3  and vama3 < vama4 and vama4 > vama5 and vama5 > vama6 and vama6 > vama7
    is_tai = vama1 < vama2 and vama2 < vama3  and vama3 < vama4 and vama4 > vama5 and vama5 > vama6 and vama6 > vama7
    is_lv = vama1 > vama2 and vama2 > vama3  and vama3 > vama4 and vama4 < vama5 and vama5 > vama6 and vama6 > vama7
    is_dui = vama1 < vama2 and vama2 > vama3  and vama3 > vama4 and vama4 < vama5 and vama5 > vama6 and vama6 > vama7
    is_kui = vama1 > vama2 and vama2 < vama3  and vama3 > vama4 and vama4 < vama5 and vama5 > vama6 and vama6 > vama7
    is_guimei = vama1 < vama2 and vama2 < vama3  and vama3 > vama4 and vama4 < vama5 and vama5 > vama6 and vama6 > vama7
    is_zhongfu = vama1 > vama2 and vama2 > vama3  and vama3 < vama4 and vama4 < vama5 and vama5 > vama6 and vama6 > vama7
    is_jie = vama1 < vama2 and vama2 > vama3  and vama3 < vama4 and vama4 < vama5 and vama5 > vama6 and vama6 > vama7
    is_sun = vama1 > vama2 and vama2 < vama3  and vama3 < vama4 and vama4 < vama5 and vama5 > vama6 and vama6 > vama7
    is_cui = vama1 < vama2 and vama2 > vama3  and vama3 > vama4 and vama4 < vama5 and vama5 < vama6 and vama6 < vama7
    is_jin2 = vama1 > vama2 and vama2 < vama3  and vama3 > vama4 and vama4 < vama5 and vama5 < vama6 and vama6 < vama7
    is_yu = vama1< vama2 and vama2 < vama3  and vama3 > vama4 and vama4 < vama5 and vama5 < vama6 and vama6 < vama7
    is_guan = vama1 > vama2 and vama2 > vama3  and vama3 < vama4 and vama4 < vama5 and vama5 < vama6 and vama6 < vama7
    is_bi = vama1 < vama2 and vama2 > vama3  and vama3 < vama4 and vama4 < vama5 and vama5 < vama6 and vama6 < vama7
    is_bo = vama1 > vama2 and vama2 < vama3  and vama3 < vama4 and vama4 < vama5 and vama5 < vama6 and vama6 < vama7


    if is_qian:
        return("乾")
    if is_kun:
        return("坤")
    if is_guai:
        return("夬")
    if is_dayou:
        return("大有")
    if is_dazhuang:
        return("大壮")
    if is_xiaoxu:
        return("小蓄")
    if is_xu:
        return("需")
    if is_daxu:
        return("大蓄")
    if is_tai:
        return("泰")
    if is_lv:
        return("履")
    if is_dui:
        return("兑")
    if is_kui:
        return("睽")
    if is_guimei:
        return("归妹")
    if is_zhongfu:
        return("中孚")
    if is_jie:
        return("节")
    if is_sun:
        return("损")
    if is_lin:
        return("临")
    if is_tongren:
        return("同人")
    if is_ge:
        return("革")
    if is_li:
        return("离")
    if is_feng:
        return("丰")
    if is_jiaren:
        return("家人")
    if is_jiji:
        return("既济")
    if is_ben:
        return("贲")
    if is_mingyi:
        return("明夷")
    if is_wuwang:
        return("无妄")
    if is_sui:
        return("随")
    if is_shike:
        return("噬嗑")
    if is_zhen:
        return("震")
    if is_yi:
        return("益")
    if is_tun:
        return("屯")
    if is_yi2:
        return("颐")
    if is_fu:
        return("复")
    if is_gou:
        return("姤")
    if is_daguo:
        return("大过")
    if is_ding:
        return("鼎")
    if is_heng:
        return("恒")
    if is_xun:
        return("巽")
    if is_jing:
        return("井")
    if is_gu:
        return("蛊")
    if is_sheng:
        return("升")
    if is_song:
        return("讼")
    if is_kun2:
        return("困")
    if is_weiji:
        return("未济")
    if is_jie:
        return("解")
    if is_huan:
        return("涣")
    if is_kan:
        return("坎")
    if is_meng:
        return("蒙")
    if is_shi:
        return("师")
    if is_dun:
        return("遁")
    if is_xian:
        return("咸")
    if is_lv2:
        return("旅")
    if is_xiaoguo:
        return("小过")
    if is_jian:
        return("渐")
    if is_jian2:
        return("蹇")
    if is_gen:
        return("艮")
    if is_qian2:
        return("谦")
    if is_pi:
        return("否")
    if is_cui:
        return("萃")
    if is_jin2:
        return("晋")
    if is_yu:
        return("豫")
    if is_guan:
        return("观")
    if is_bi:
        return("比")
    if is_bo:
        return("剥")
